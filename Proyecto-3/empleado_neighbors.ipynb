# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn import preprocessing

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('employee_promotion.csv')

# %%
df.dtypes
# Out:
# employee_id               int64
# department               object
# region                   object
# education                object
# gender                   object
# recruitment_channel      object
# no_of_trainings           int64
# age                       int64
# previous_year_rating    float64
# length_of_service         int64
# awards_won                int64
# avg_training_score      float64
# is_promoted               int64
# dtype: object

# %%
df.head()
# Out:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
# 2         7513  Sales & Marketing  region_19        Bachelor's      m
# 3         2542  Sales & Marketing  region_23        Bachelor's      m
# 4        48945         Technology  region_26        Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
# 1               other                1   30                   5.0
# 2            sourcing                1   34                   3.0
# 3               other                2   39                   1.0
# 4               other                1   45                   3.0
#
#    length_of_service  awards_won  avg_training_score  is_promoted
# 0                  8           0                49.0            0
# 1                  4           0                60.0            0
# 2                  7           0                50.0            0
# 3                 10           0                50.0            0
# 4                  2           0                73.0            0

# %%
df.gender.unique()
# Out:
# array(['f', 'm'], dtype=object)

# %%
df.gender = df.gender.map({'m' : 1, 'f' : 2})

# %%
df.describe()
# Out:
#         employee_id        gender  no_of_trainings           age  \
# count  54808.000000  54808.000000     54808.000000  54808.000000
# mean   39195.830627      1.297621         1.253011     34.803915
# std    22586.581449      0.457216         0.609264      7.660169
# min        1.000000      1.000000         1.000000     20.000000
# 25%    19669.750000      1.000000         1.000000     29.000000
# 50%    39225.500000      1.000000         1.000000     33.000000
# 75%    58730.500000      2.000000         1.000000     39.000000
# max    78298.000000      2.000000        10.000000     60.000000
#
#        previous_year_rating  length_of_service    awards_won  \
# count          50684.000000       54808.000000  54808.000000
# mean               3.329256           5.865512      0.023172
# std                1.259993           4.265094      0.150450
# min                1.000000           1.000000      0.000000
# 25%                3.000000           3.000000      0.000000
# 50%                3.000000           5.000000      0.000000
# 75%                4.000000           7.000000      0.000000
# max                5.000000          37.000000      1.000000
#
#        avg_training_score   is_promoted
# count        52248.000000  54808.000000
# mean            63.712238      0.085170
# std             13.521910      0.279137
# min             39.000000      0.000000
# 25%             51.000000      0.000000
# 50%             60.000000      0.000000
# 75%             77.000000      0.000000
# max             99.000000      1.000000

# %%
df.head()
# Out:
#    employee_id         department     region         education  gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above       2
# 1        65141         Operations  region_22        Bachelor's       1
# 2         7513  Sales & Marketing  region_19        Bachelor's       1
# 3         2542  Sales & Marketing  region_23        Bachelor's       1
# 4        48945         Technology  region_26        Bachelor's       1
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
# 1               other                1   30                   5.0
# 2            sourcing                1   34                   3.0
# 3               other                2   39                   1.0
# 4               other                1   45                   3.0
#
#    length_of_service  awards_won  avg_training_score  is_promoted
# 0                  8           0                49.0            0
# 1                  4           0                60.0            0
# 2                  7           0                50.0            0
# 3                 10           0                50.0            0
# 4                  2           0                73.0            0

# %%
df.department.unique()
# Out:
# array(['Sales & Marketing', 'Operations', 'Technology', 'Analytics',
#        'R&D', 'Procurement', 'Finance', 'HR', 'Legal'], dtype=object)

# %%
df.department = df.department.map({'Sales & Marketing': 1, 'Operations': 2, 'Technology': 3, 'Analytics': 4,
       'R&D': 5, 'Procurement': 6, 'Finance': 7, 'HR': 8, 'Legal': 9})

# %%
df.education.unique()
# Out:
# array(["Master's & above", "Bachelor's", nan, 'Below Secondary'],
#       dtype=object)

# %%
df.education = df.education.map({"Master's & above": 1, "Bachelor's":2, 'Below Secondary': 4})

# %%
df.recruitment_channel.unique()
# Out:
# array(['sourcing', 'other', 'referred'], dtype=object)

# %%
df.recruitment_channel = df.recruitment_channel.map({'sourcing': 1, 'other': 2, 'referred': 3})

# %%
df.head()
# Out:
#    employee_id  department     region  education  gender  recruitment_channel  \
# 0        65438           1   region_7        1.0       2                    1
# 1        65141           2  region_22        2.0       1                    2
# 2         7513           1  region_19        2.0       1                    1
# 3         2542           1  region_23        2.0       1                    2
# 4        48945           3  region_26        2.0       1                    2
#
#    no_of_trainings  age  previous_year_rating  length_of_service  awards_won  \
# 0                1   35                   5.0                  8           0
# 1                1   30                   5.0                  4           0
# 2                1   34                   3.0                  7           0
# 3                2   39                   1.0                 10           0
# 4                1   45                   3.0                  2           0
#
#    avg_training_score  is_promoted
# 0                49.0            0
# 1                60.0            0
# 2                50.0            0
# 3                50.0            0
# 4                73.0            0

# %%
df.region.unique()
# Out:
# array(['region_7', 'region_22', 'region_19', 'region_23', 'region_26',
#        'region_2', 'region_20', 'region_34', 'region_1', 'region_4',
#        'region_29', 'region_31', 'region_15', 'region_14', 'region_11',
#        'region_5', 'region_28', 'region_17', 'region_13', 'region_16',
#        'region_25', 'region_10', 'region_27', 'region_30', 'region_12',
#        'region_21', 'region_8', 'region_32', 'region_6', 'region_33',
#        'region_24', 'region_3', 'region_9', 'region_18'], dtype=object)

# %%
df.region = df.region.str.strip()

# %%
lencoder_region = preprocessing.LabelEncoder()

# %%
lencoder_region.fit(df.region)
# Out:
# LabelEncoder()

# %%
df.region = lencoder_region.transform(df.region)

# %%
df.tail(10)
# Out:
#        employee_id  department  region  education  gender  \
# 54798        40257           1      11        1.0       2
# 54799        68093           6      11        1.0       2
# 54800        39227           8       2        2.0       1
# 54801        12431           3      18        2.0       2
# 54802         6915           1       5        2.0       1
# 54803         3030           3       5        2.0       1
# 54804        74592           2      19        1.0       2
# 54805        13918           4       0        2.0       1
# 54806        13614           1      33        NaN       1
# 54807        51526           8      14        2.0       1
#
#        recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 54798                    2                2   40                   5.0
# 54799                    2                1   50                   5.0
# 54800                    2                2   34                   5.0
# 54801                    1                1   31                   NaN
# 54802                    2                2   31                   1.0
# 54803                    1                1   48                   3.0
# 54804                    2                1   37                   2.0
# 54805                    2                1   27                   5.0
# 54806                    1                1   29                   1.0
# 54807                    2                1   27                   1.0
#
#        length_of_service  awards_won  avg_training_score  is_promoted
# 54798                  4           0                51.0            0
# 54799                  6           1                67.0            0
# 54800                  3           0                52.0            0
# 54801                  1           0                78.0            0
# 54802                  2           0                49.0            0
# 54803                 17           0                78.0            0
# 54804                  6           0                56.0            0
# 54805                  3           0                79.0            0
# 54806                  2           0                 NaN            0
# 54807                  5           0                49.0            0

# %%
df.education.unique()
# Out:
# array([ 1.,  2., nan,  4.])

# %%
df.dtypes
# Out:
# employee_id               int64
# department                int64
# region                    int32
# education               float64
# gender                    int64
# recruitment_channel       int64
# no_of_trainings           int64
# age                       int64
# previous_year_rating    float64
# length_of_service         int64
# awards_won                int64
# avg_training_score      float64
# is_promoted               int64
# dtype: object

# %%
corr = round(df.corr(), 4)
corr.style.background_gradient()
# Out:
# <style type="text/css">
# #T_e2929_row0_col0, #T_e2929_row1_col1, #T_e2929_row2_col2, #T_e2929_row3_col3, #T_e2929_row4_col4, #T_e2929_row5_col5, #T_e2929_row6_col6, #T_e2929_row7_col7, #T_e2929_row8_col8, #T_e2929_row9_col9, #T_e2929_row10_col10, #T_e2929_row11_col11, #T_e2929_row12_col12 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_e2929_row0_col1, #T_e2929_row2_col8, #T_e2929_row3_col8, #T_e2929_row5_col1, #T_e2929_row10_col1, #T_e2929_row12_col6 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_e2929_row0_col2, #T_e2929_row0_col4, #T_e2929_row3_col2, #T_e2929_row5_col4, #T_e2929_row5_col6, #T_e2929_row5_col8, #T_e2929_row10_col2 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_e2929_row0_col3, #T_e2929_row2_col3, #T_e2929_row10_col3 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_e2929_row0_col5, #T_e2929_row1_col0, #T_e2929_row9_col12, #T_e2929_row10_col0 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_e2929_row0_col6, #T_e2929_row1_col2, #T_e2929_row1_col6, #T_e2929_row2_col6, #T_e2929_row2_col11, #T_e2929_row10_col6 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_e2929_row0_col7 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_e2929_row0_col8, #T_e2929_row4_col2, #T_e2929_row5_col2, #T_e2929_row7_col8, #T_e2929_row8_col10 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_e2929_row0_col9, #T_e2929_row8_col9, #T_e2929_row12_col8 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_e2929_row0_col10, #T_e2929_row0_col11, #T_e2929_row5_col10, #T_e2929_row12_col1 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_e2929_row0_col12, #T_e2929_row1_col12, #T_e2929_row3_col5, #T_e2929_row9_col6, #T_e2929_row10_col5 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_e2929_row1_col3 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_e2929_row1_col4 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_e2929_row1_col5, #T_e2929_row5_col12, #T_e2929_row6_col10, #T_e2929_row7_col10, #T_e2929_row9_col2 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_e2929_row1_col7 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_e2929_row1_col8, #T_e2929_row8_col11, #T_e2929_row10_col11, #T_e2929_row11_col6 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_e2929_row1_col9 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_e2929_row1_col10, #T_e2929_row6_col1, #T_e2929_row8_col5 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_e2929_row1_col11, #T_e2929_row11_col1 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_e2929_row2_col0, #T_e2929_row2_col5, #T_e2929_row3_col0, #T_e2929_row3_col7, #T_e2929_row3_col9, #T_e2929_row3_col12, #T_e2929_row4_col6, #T_e2929_row5_col0, #T_e2929_row6_col0, #T_e2929_row6_col4, #T_e2929_row6_col8, #T_e2929_row6_col12, #T_e2929_row7_col1, #T_e2929_row7_col2, #T_e2929_row7_col3, #T_e2929_row7_col6, #T_e2929_row7_col11, #T_e2929_row9_col1, #T_e2929_row9_col10 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_e2929_row2_col1, #T_e2929_row2_col10, #T_e2929_row3_col10, #T_e2929_row3_col11, #T_e2929_row4_col10 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_e2929_row2_col4, #T_e2929_row5_col11, #T_e2929_row9_col8 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_e2929_row2_col7, #T_e2929_row10_col12 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_e2929_row2_col9, #T_e2929_row6_col9 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_e2929_row2_col12, #T_e2929_row4_col12, #T_e2929_row11_col5 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_e2929_row3_col1, #T_e2929_row4_col8, #T_e2929_row6_col11, #T_e2929_row10_col8, #T_e2929_row12_col2, #T_e2929_row12_col4 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_e2929_row3_col4, #T_e2929_row4_col11 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_e2929_row3_col6, #T_e2929_row8_col1, #T_e2929_row11_col10 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_e2929_row4_col0, #T_e2929_row7_col0, #T_e2929_row7_col12, #T_e2929_row9_col0, #T_e2929_row11_col0, #T_e2929_row12_col0 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_e2929_row4_col1 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_e2929_row4_col3, #T_e2929_row12_col7 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_e2929_row4_col5, #T_e2929_row6_col5, #T_e2929_row8_col6, #T_e2929_row12_col5 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_e2929_row4_col7 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_e2929_row4_col9, #T_e2929_row6_col7, #T_e2929_row12_col11 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_e2929_row5_col3, #T_e2929_row8_col7 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_e2929_row5_col7, #T_e2929_row8_col3, #T_e2929_row10_col7, #T_e2929_row11_col3 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_e2929_row5_col9, #T_e2929_row11_col12 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_e2929_row6_col2, #T_e2929_row8_col2, #T_e2929_row10_col4 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_e2929_row6_col3 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_e2929_row7_col4, #T_e2929_row9_col3 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_e2929_row7_col5, #T_e2929_row8_col0, #T_e2929_row9_col5, #T_e2929_row9_col11 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_e2929_row7_col9 {
#   background-color: #0d75b3;
#   color: #f1f1f1;
# }
# #T_e2929_row8_col4, #T_e2929_row11_col2, #T_e2929_row11_col4 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_e2929_row8_col12, #T_e2929_row11_col9 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_e2929_row9_col4 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_e2929_row9_col7 {
#   background-color: #056faf;
#   color: #f1f1f1;
# }
# #T_e2929_row10_col9 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_e2929_row11_col7 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_e2929_row11_col8 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_e2929_row12_col3 {
#   background-color: #cccfe5;
#   color: #000000;
# }
# #T_e2929_row12_col9 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_e2929_row12_col10 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# </style>
# <table id="T_e2929">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e2929_level0_col0" class="col_heading level0 col0" >employee_id</th>
#       <th id="T_e2929_level0_col1" class="col_heading level0 col1" >department</th>
#       <th id="T_e2929_level0_col2" class="col_heading level0 col2" >region</th>
#       <th id="T_e2929_level0_col3" class="col_heading level0 col3" >education</th>
#       <th id="T_e2929_level0_col4" class="col_heading level0 col4" >gender</th>
#       <th id="T_e2929_level0_col5" class="col_heading level0 col5" >recruitment_channel</th>
#       <th id="T_e2929_level0_col6" class="col_heading level0 col6" >no_of_trainings</th>
#       <th id="T_e2929_level0_col7" class="col_heading level0 col7" >age</th>
#       <th id="T_e2929_level0_col8" class="col_heading level0 col8" >previous_year_rating</th>
#       <th id="T_e2929_level0_col9" class="col_heading level0 col9" >length_of_service</th>
#       <th id="T_e2929_level0_col10" class="col_heading level0 col10" >awards_won</th>
#       <th id="T_e2929_level0_col11" class="col_heading level0 col11" >avg_training_score</th>
#       <th id="T_e2929_level0_col12" class="col_heading level0 col12" >is_promoted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e2929_level0_row0" class="row_heading level0 row0" >employee_id</th>
#       <td id="T_e2929_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_e2929_row0_col1" class="data row0 col1" >0.006800</td>
#       <td id="T_e2929_row0_col2" class="data row0 col2" >-0.003400</td>
#       <td id="T_e2929_row0_col3" class="data row0 col3" >-0.004300</td>
#       <td id="T_e2929_row0_col4" class="data row0 col4" >0.001500</td>
#       <td id="T_e2929_row0_col5" class="data row0 col5" >-0.005400</td>
#       <td id="T_e2929_row0_col6" class="data row0 col6" >-0.005100</td>
#       <td id="T_e2929_row0_col7" class="data row0 col7" >0.000400</td>

# %%
df.drop(['employee_id', 'previous_year_rating'], axis = 1, inplace = True)

# %%
df.head()
# Out:
#    department  region  education  gender  recruitment_channel  \
# 0           1      31        1.0       2                    1
# 1           2      14        2.0       1                    2
# 2           1      10        2.0       1                    1
# 3           1      15        2.0       1                    2
# 4           3      18        2.0       1                    2
#
#    no_of_trainings  age  length_of_service  awards_won  avg_training_score  \
# 0                1   35                  8           0                49.0
# 1                1   30                  4           0                60.0
# 2                1   34                  7           0                50.0
# 3                2   39                 10           0                50.0
# 4                1   45                  2           0                73.0
#
#    is_promoted
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0

# %%
data_x = df.drop(['recruitment_channel', 'awards_won','is_promoted'], axis='columns')
data_y = df.is_promoted

# %%
df.describe()
# Out:
#          department        region     education        gender  \
# count  54808.000000  54808.000000  52399.000000  54808.000000
# mean       3.222668     15.428970      1.745892      1.297621
# std        2.292378      8.764954      0.530773      0.457216
# min        1.000000      0.000000      1.000000      1.000000
# 25%        1.000000     11.000000      1.000000      1.000000
# 50%        2.000000     14.000000      2.000000      1.000000
# 75%        5.000000     21.000000      2.000000      2.000000
# max        9.000000     33.000000      4.000000      2.000000
#
#        recruitment_channel  no_of_trainings           age  length_of_service  \
# count         54808.000000     54808.000000  54808.000000       54808.000000
# mean              1.597176         1.253011     34.803915           5.865512
# std               0.531258         0.609264      7.660169           4.265094
# min               1.000000         1.000000     20.000000           1.000000
# 25%               1.000000         1.000000     29.000000           3.000000
# 50%               2.000000         1.000000     33.000000           5.000000
# 75%               2.000000         1.000000     39.000000           7.000000
# max               3.000000        10.000000     60.000000          37.000000
#
#          awards_won  avg_training_score   is_promoted
# count  54808.000000        52248.000000  54808.000000
# mean       0.023172           63.712238      0.085170
# std        0.150450           13.521910      0.279137
# min        0.000000           39.000000      0.000000
# 25%        0.000000           51.000000      0.000000
# 50%        0.000000           60.000000      0.000000
# 75%        0.000000           77.000000      0.000000
# max        1.000000           99.000000      1.000000

# %%
data_x.education = data_x.education.fillna(data_x.education.mean())

# %%
data_x.avg_training_score = data_x.avg_training_score.fillna(data_x.avg_training_score.mean())

# %%
data_x
# Out:
#        department  region  education  gender  no_of_trainings  age  \
# 0               1      31   1.000000       2                1   35
# 1               2      14   2.000000       1                1   30
# 2               1      10   2.000000       1                1   34
# 3               1      15   2.000000       1                2   39
# 4               3      18   2.000000       1                1   45
# ...           ...     ...        ...     ...              ...  ...
# 54803           3       5   2.000000       1                1   48
# 54804           2      19   1.000000       2                1   37
# 54805           4       0   2.000000       1                1   27
# 54806           1      33   1.745892       1                1   29
# 54807           8      14   2.000000       1                1   27
#
#        length_of_service  avg_training_score
# 0                      8           49.000000
# 1                      4           60.000000
# 2                      7           50.000000
# 3                     10           50.000000
# 4                      2           73.000000
# ...                  ...                 ...
# 54803                 17           78.000000
# 54804                  6           56.000000
# 54805                  3           79.000000
# 54806                  2           63.712238
# 54807                  5           49.000000
#
# [54808 rows x 8 columns]

# %%
data_y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 54803    0
# 54804    0
# 54805    0
# 54806    0
# 54807    0
# Name: is_promoted, Length: 54808, dtype: int64

# %%
df.is_promoted.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
train_x, test_x, train_y, test_y = train_test_split(data_x, data_y, test_size = 0.1)

# %%
k_neighbors = KNeighborsClassifier(n_neighbors=7)

# %%
k_neighbors.fit(train_x, train_y)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
y_predicted = k_neighbors.predict(test_x)

# %%
print(f'Score: {round(k_neighbors.score(test_x, test_y), 4) * 100}%')
# Out:
# Score: 92.06%

# %%
genre = ['None', 'masculino', 'femenino']
educacion = ['None',"Master's & above", "Bachelor's", 'Below Secondary']
departament = ['Sales & Marketing', 'Operations', 'Technology', 'Analytics',
       'R&D', 'Procurement', 'Finance', 'HR', 'Legal']
promoved = ['no promovido', 'promovido']

department = 7
region = 28
gender = 2
education = 2
age = 36
length_of_service = 8
avg_training_score = 92.00
no_of_trainings = 4

# %%
def empleado_classify(model, age, gender, region, department, length_of_service, avg_training_score, no_of_trainings, education):
    predicted =  model.predict([[age, gender, region, department, length_of_service, avg_training_score, no_of_trainings, education]])
    print(f'El / la empleado(a) de sexo {genre[gender]}, de {age} años, con grado de educacion {educacion[education]}, perteneciente al departamento de {departament[department]}, region {region} y que tiene {length_of_service} años de servicio, realizo {no_of_trainings} entrenamiento, con puntuacion de {avg_training_score}:sera {promoved[predicted[0]]}')

# %%
empleado_classify(k_neighbors, age, gender, region, department, length_of_service, avg_training_score, no_of_trainings, education)
# Out:
# El / la empleado(a) de sexo femenino, de 36 años, con grado de educacion Bachelor's, perteneciente al departamento de HR, region 28 y que tiene 8 años de servicio, realizo 4 entrenamiento, con puntuacion de 92.0:sera no promovido
# c:\Users\Asus\Desktop\PCode\Pandas\entorno_v\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
