# %% [markdown]
# # Introducción a Pandas

# %% [markdown]
# El primer paso para utilizar pandas, es importar la librería

# %%
import pandas as pd

# %% [markdown]
# El siguiente paso es cargar los datos a un DataFrame

# %%
df = pd.read_csv('titles.csv')

# %% [markdown]
# ### Visualización de Datos

# %%
# Sirve para ver los 5 primeros registros, o si se le proporciona, los n primeros registros
df.head(9)
# Out:
#          id                        title   type  \
# 0   tm87233        It's a Wonderful Life  MOVIE
# 1  tm143047                    Duck Soup  MOVIE
# 2   tm83884              His Girl Friday  MOVIE
# 3   ts20945            The Three Stooges   SHOW
# 4    tm5012                    Red River  MOVIE
# 5   ts37076       The Jack Benny Program   SHOW
# 6   tm82253  The Best Years of Our Lives  MOVIE
# 7   tm88469            The Bishop's Wife  MOVIE
# 8   tm82560             The Little Foxes  MOVIE
#
#                                          description  release_year  \
# 0  A holiday favourite for generations...  George...          1946
# 1  Rufus T. Firefly is named president/dictator o...          1933
# 2  Hildy, the journalist former wife of newspaper...          1940
# 3  The Three Stooges were an American vaudeville ...          1934
# 4  Headstrong Thomas Dunson starts a thriving Tex...          1948
# 5  Laugh along with funnyman Jack Benny as he bri...          1950
# ...

# %%
# Funciona igual que .head()
df.tail(11)
# Out:
#               id                               title   type  \
# 10862   tm948025                 Hard Luck Love Song  MOVIE
# 10863   tm811070           The Man on the Other Side  MOVIE
# 10864   ts360904                Work It Out Wombats!   SHOW
# 10865   ts382337                Marc Marquez: ALL IN   SHOW
# 10866  tm1305701                     Casando a mi Ex  MOVIE
# 10867   ts199693                                 A2Z   SHOW
# 10868  tm1292884                                Hunt  MOVIE
# 10869  tm1284753                  Ennalum Ente Aliya  MOVIE
# 10870  tm1303380  Anubhav Singh Bassi: Bas Kar Bassi  MOVIE
# 10871  tm1307408     Pinkfong! Summer in Wonderville  MOVIE
# 10872  tm1297385                            Chapelle  MOVIE
#
#                                              description  release_year  \
# 10862  Jesse, a charismatic but down on his luck trou...          2023
# 10863  It is 1974, and in the Cold War paranoia of Ea...          2023
# ...

# %% [markdown]
# ### Descripción de Datos

# %%
df.describe()
# Out:
#        release_year       runtime      seasons   imdb_score    imdb_votes  \
# count  10873.000000  10873.000000  1551.000000  9765.000000  9.753000e+03
# mean    2004.077807     85.869033     2.661509     5.970558  8.973232e+03
# std       24.883711     34.156332     3.719633     1.362815  4.897767e+04
# min     1912.000000      0.000000     1.000000     1.100000  5.000000e+00
# 25%     2002.000000     65.000000     1.000000     5.100000  1.190000e+02
# 50%     2015.000000     89.000000     1.000000     6.100000  4.880000e+02
# 75%     2019.000000    102.000000     3.000000     7.000000  2.493000e+03
# max     2023.000000    940.000000    53.000000     9.900000  2.081757e+06
#
#        tmdb_popularity   tmdb_score
# count     10302.000000  8747.000000
# mean          7.614083     5.977729
# std          45.845289     1.512941
# min           0.000153     0.500000
# 25%           1.327250     5.066500
# 50%           2.658500     6.000000
# 75%           6.185000     6.983000
# ...

# %% [markdown]
# ### Reordenamiento de los datos

# %% [markdown]
# Para esto utilizaremos el método .sample() para tomar una muestra de los datos de acuerdo
# a un porcentaje

# %%
disorder_df = df.sample(frac=0.25)

# %% [markdown]
# ### Conocer el tipo de información que tinen nuestras características

# %%
df.dtypes
# Out:
# id                       object
# title                    object
# type                     object
# description              object
# release_year              int64
# age_certification        object
# runtime                   int64
# genres                   object
# production_countries     object
# seasons                 float64
# imdb_id                  object
# imdb_score              float64
# imdb_votes              float64
# tmdb_popularity         float64
# tmdb_score              float64
# dtype: object

# %% [markdown]
# ### Filtrado por columnas

# %%
genres = df.genres
titles = df['title']

# %% [markdown]
# ### Porción de datos de una columna

# %%
df.release_year[::5]
# [:] Todos los elementos
# [n:] Desde el elemento n en adelante
# [:n] Desde el inicio hasta el elemento n
# [n:m] Desde el elemento n al elemento m
# [n:m:s]  Desde el elemento n al elemento m en s pasos
# Out:
# 0        1946
# 5        1950
# 10       1925
# 15       1936
# 20       1942
#          ...
# 10850    2023
# 10855    2023
# 10860    2023
# 10865    2023
# 10870    2023
# Name: release_year, Length: 2175, dtype: int64

# %% [markdown]
# ### Filtros Avanzados
# Podemos realizar queries complejos y limitar el DataFrame a aquellos valores que cumplan determinada condición

# %%
df_before_2000 = df[df['release_year'] < 2000]

# %%
df_before_2000.release_year.unique()
# Out:
# array([1946, 1933, 1940, 1934, 1948, 1950, 1947, 1941, 1939, 1925, 1926,
#        1936, 1919, 1927, 1942, 1945, 1932, 1922, 1915, 1918, 1937, 1935,
#        1943, 1931, 1938, 1924, 1944, 1916, 1923, 1949, 1928, 1921, 1920,
#        1930, 1929, 1913, 1912, 1914, 1917, 1976, 1957, 1968, 1979, 1969,
#        1961, 1972, 1977, 1965, 1962, 1980, 1975, 1973, 1958, 1955, 1978,
#        1971, 1970, 1967, 1959, 1964, 1966, 1963, 1956, 1953, 1952, 1974,
#        1960, 1954, 1951, 1981, 1985, 1989, 1984, 1982, 1988, 1986, 1990,
#        1987, 1983, 1997, 1998, 1994, 1999, 1993, 1995, 1992, 1996, 1991],
#       dtype=int64)

# %% [markdown]
# ### Filtros Compuestos

# %%
selected_years = [1989, 1994, 1998, 2005]
df[df.release_year.isin(selected_years)]
# Out:
#             id                                       title   type  \
# 1672  tm140316          Indiana Jones and the Last Crusade  MOVIE
# 1675  tm140433                                  Road House  MOVIE
# 1680   tm63423                                    Heathers  MOVIE
# 1692   ts88551                            Wallace & Gromit   SHOW
# 1696   ts41693                        The Kids in the Hall   SHOW
# ...        ...                                         ...    ...
# 3796  tm170312                 The Da Vinci Code Deception  MOVIE
# 3806  tm685129                           Me and the Mosque  MOVIE
# 3842  ts182912   A History of Black Achievement in America   SHOW
# 3846  tm602733                            Munnabhai S.S.C.  MOVIE
# 3851   ts98392  Technological Marvels of the Ancient World   SHOW
#
#                                             description  release_year  \
# 1672  In 1938, an art collector appeals to eminent a...          1989
# ...

# %% [markdown]
# ### Agrupación en Pandas

# %%
grouped_by_type = df.groupby(by=['type'])

# %%
grouped_by_type['release_year'].describe()
# Out:
#         count         mean        std     min     25%     50%     75%     max
# type
# MOVIE  9322.0  2002.587642  26.144222  1912.0  1999.0  2015.0  2019.0  2023.0
# SHOW   1551.0  2013.034172  11.797298  1934.0  2011.0  2017.0  2020.0  2023.0

# %% [markdown]
# ### Manipulación de Datos

# %% [markdown]
# **Limpieza de valores nulos**

# %%
# Limpiar de acuerdo a las filas
without_null_rows = df.dropna(axis='index')
# Limpiar de acuerdo a las columnas
without_null_columns = df.dropna(axis=1)

# %%
print(len(without_null_rows))
print(len(without_null_columns))
# Out:
# 724
# 10873

# %%
df_before_2000.dropna(axis=0, inplace=True)
# Out:
# C:\Users\Eduardo Flores\AppData\Local\Temp\ipykernel_12344\4117459487.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_before_2000.dropna(axis=0, inplace=True)

# %%
df_before_2000.release_year.unique()
# Out:
# array([1934, 1961, 1968, 1972, 1965, 1979, 1975, 1976, 1970, 1966, 1958,
#        1974, 1971, 1960, 1953, 1956, 1952, 1967, 1982, 1990, 1981, 1989,
#        1986, 1983, 1984, 1987, 1985, 1997, 1999, 1995, 1992, 1996, 1993,
#        1998, 1994, 1991], dtype=int64)

# %% [markdown]
# **Conversión de valores nulos**

# %%
df2 = df.fillna(0)

# %%
df2.describe()
# Out:
#        release_year       runtime       seasons    imdb_score    imdb_votes  \
# count  10873.000000  10873.000000  10873.000000  10873.000000  1.087300e+04
# mean    2004.077807     85.869033      0.379656      5.362136  8.048922e+03
# std       24.883711     34.156332      1.684911      2.220525  4.646648e+04
# min     1912.000000      0.000000      0.000000      0.000000  0.000000e+00
# 25%     2002.000000     65.000000      0.000000      4.600000  6.600000e+01
# 50%     2015.000000     89.000000      0.000000      5.800000  3.540000e+02
# 75%     2019.000000    102.000000      0.000000      6.800000  1.978000e+03
# max     2023.000000    940.000000     53.000000      9.900000  2.081757e+06
#
#        tmdb_popularity    tmdb_score
# count     10873.000000  10873.000000
# mean          7.214227      4.808902
# std          44.657462      2.731789
# min           0.000000      0.000000
# 25%           1.143000      3.800000
# 50%           2.467000      5.700000
# ...

# %%
df.tmdb_score.fillna(df.tmdb_score.mean(), inplace=True)

# %%
df.describe()
# Out:
#        release_year       runtime      seasons   imdb_score    imdb_votes  \
# count  10873.000000  10873.000000  1551.000000  9765.000000  9.753000e+03
# mean    2004.077807     85.869033     2.661509     5.970558  8.973232e+03
# std       24.883711     34.156332     3.719633     1.362815  4.897767e+04
# min     1912.000000      0.000000     1.000000     1.100000  5.000000e+00
# 25%     2002.000000     65.000000     1.000000     5.100000  1.190000e+02
# 50%     2015.000000     89.000000     1.000000     6.100000  4.880000e+02
# 75%     2019.000000    102.000000     3.000000     7.000000  2.493000e+03
# max     2023.000000    940.000000    53.000000     9.900000  2.081757e+06
#
#        tmdb_popularity    tmdb_score
# count     10302.000000  10873.000000
# mean          7.614083      5.977729
# std          45.845289      1.356975
# min           0.000153      0.500000
# 25%           1.327250      5.400000
# 50%           2.658500      5.977729
# ...

# %% [markdown]
# ### Elimina los valores duplicados

# %%
df3 = df['release_year'].drop_duplicates()

# %%
df3.describe()
# Out:
# count     112.000000
# mean     1967.500000
# std        32.475632
# min      1912.000000
# 25%      1939.750000
# 50%      1967.500000
# 75%      1995.250000
# max      2023.000000
# Name: release_year, dtype: float64

# %% [markdown]
# ### Conservar o extraer columnas

# %%
scores = df.drop(['id','title','type','description','release_year','age_certification','runtime','genres','production_countries','seasons','imdb_id','imdb_votes','tmdb_popularity'], axis=1)

# %%
scores
# Out:
#        imdb_score  tmdb_score
# 0             8.6    8.261000
# 1             7.8    7.357000
# 2             7.8    7.433000
# 3             8.5    7.600000
# 4             7.8    7.400000
# ...           ...         ...
# 10868         5.8    4.300000
# 10869         5.6    8.000000
# 10870         8.3    5.977729
# 10871         NaN    5.977729
# 10872         NaN    5.977729
#
# [10873 rows x 2 columns]

# %%
target = df.release_year

# %%
target
# Out:
# 0        1946
# 1        1933
# 2        1940
# 3        1934
# 4        1948
#          ...
# 10868    2023
# 10869    2023
# 10870    2023
# 10871    2023
# 10872    2023
# Name: release_year, Length: 10873, dtype: int64

# %% [markdown]
# ### Conversión de texto a valores numéricos

# %%
df.type.unique()
# Out:
# array(['MOVIE', 'SHOW'], dtype=object)

# %%
df.type = df.type.map({'MOVIE': 1, 'SHOW': 2})

# %%
df.describe()
# Out:
#                type  release_year       runtime      seasons   imdb_score  \
# count  10873.000000  10873.000000  10873.000000  1551.000000  9765.000000
# mean       1.142647   2004.077807     85.869033     2.661509     5.970558
# std        0.349729     24.883711     34.156332     3.719633     1.362815
# min        1.000000   1912.000000      0.000000     1.000000     1.100000
# 25%        1.000000   2002.000000     65.000000     1.000000     5.100000
# 50%        1.000000   2015.000000     89.000000     1.000000     6.100000
# 75%        1.000000   2019.000000    102.000000     3.000000     7.000000
# max        2.000000   2023.000000    940.000000    53.000000     9.900000
#
#          imdb_votes  tmdb_popularity    tmdb_score
# count  9.753000e+03     10302.000000  10873.000000
# mean   8.973232e+03         7.614083      5.977729
# std    4.897767e+04        45.845289      1.356975
# min    5.000000e+00         0.000153      0.500000
# ...

# %% [markdown]
# ### Análisis de Correlación

# %%
data_x = df.drop(['id','title','description','age_certification', 'genres','production_countries','imdb_id','tmdb_popularity'], axis='columns')

# %%
data_x.corr()
# Out:
#                   type  release_year   runtime   seasons  imdb_score  \
# type          1.000000      0.146821 -0.591302       NaN    0.344459
# release_year  0.146821      1.000000  0.058485 -0.426794    0.023712
# runtime      -0.591302      0.058485  1.000000 -0.087803   -0.098841
# seasons            NaN     -0.426794 -0.087803  1.000000    0.018968
# imdb_score    0.344459      0.023712 -0.098841  0.018968    1.000000
# imdb_votes    0.005321      0.007418  0.103828  0.098564    0.159119
# tmdb_score    0.251927      0.093536 -0.049819  0.059882    0.513521
#
#               imdb_votes  tmdb_score
# type            0.005321    0.251927
# release_year    0.007418    0.093536
# runtime         0.103828   -0.049819
# seasons         0.098564    0.059882
# imdb_score      0.159119    0.513521
# imdb_votes      1.000000    0.146056
# tmdb_score      0.146056    1.000000

# %%
corr = round( data_x.corr(), 3)
corr.style.background_gradient()
# Out:
# <style type="text/css">
# #T_0c2a6_row0_col0, #T_0c2a6_row1_col1, #T_0c2a6_row2_col2, #T_0c2a6_row3_col3, #T_0c2a6_row4_col4, #T_0c2a6_row5_col5, #T_0c2a6_row6_col6 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_0c2a6_row0_col1 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_0c2a6_row0_col2, #T_0c2a6_row0_col5, #T_0c2a6_row1_col3, #T_0c2a6_row1_col5, #T_0c2a6_row2_col0, #T_0c2a6_row2_col4, #T_0c2a6_row2_col6, #T_0c2a6_row3_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_0c2a6_row0_col3, #T_0c2a6_row3_col0 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_0c2a6_row0_col4 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_0c2a6_row0_col6 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_0c2a6_row1_col0 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_0c2a6_row1_col2 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_0c2a6_row1_col4 {
#   background-color: #eee9f3;
# ...
