# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('dataset_fish.csv')

# %%
df.head()
# Out:
#   Species  Weight  Length1  Length2  Length3   Height   Width
# 0   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340

# %%
df.dtypes
# Out:
# Species     object
# Weight     float64
# Length1    float64
# Length2    float64
# Length3    float64
# Height     float64
# Width      float64
# dtype: object

# %%
df.describe()
# Out:
#             Weight     Length1     Length2     Length3      Height       Width
# count   159.000000  159.000000  159.000000  159.000000  159.000000  159.000000
# mean    398.326415   26.247170   28.415723   31.227044    8.970994    4.417486
# std     357.978317    9.996441   10.716328   11.610246    4.286208    1.685804
# min       0.000000    7.500000    8.400000    8.800000    1.728400    1.047600
# 25%     120.000000   19.050000   21.000000   23.150000    5.944800    3.385650
# 50%     273.000000   25.200000   27.300000   29.400000    7.786000    4.248500
# 75%     650.000000   32.700000   35.500000   39.650000   12.365900    5.584500
# max    1650.000000   59.000000   63.400000   68.000000   18.957000    8.142000

# %%
df.Species = df.Species.map({'Bream':1,'Roach':2, 'Whitefish': 3,'Parkki':4, 'Perch':5,'Pike':6,'Smelt':7 })

# %%
df.describe()
# Out:
#           Species       Weight     Length1     Length2     Length3  \
# count  159.000000   159.000000  159.000000  159.000000  159.000000
# mean     3.880503   398.326415   26.247170   28.415723   31.227044
# std      2.026298   357.978317    9.996441   10.716328   11.610246
# min      1.000000     0.000000    7.500000    8.400000    8.800000
# 25%      2.000000   120.000000   19.050000   21.000000   23.150000
# 50%      5.000000   273.000000   25.200000   27.300000   29.400000
# 75%      5.000000   650.000000   32.700000   35.500000   39.650000
# max      7.000000  1650.000000   59.000000   63.400000   68.000000
#
#            Height       Width
# count  159.000000  159.000000
# mean     8.970994    4.417486
# std      4.286208    1.685804
# min      1.728400    1.047600
# 25%      5.944800    3.385650
# 50%      7.786000    4.248500
# 75%     12.365900    5.584500
# max     18.957000    8.142000

# %%
corr = round(df.corr(),4)
corr.style.background_gradient()
# Out:
# <style type="text/css">
# #T_74efe_row0_col0, #T_74efe_row1_col1, #T_74efe_row2_col2, #T_74efe_row2_col3, #T_74efe_row3_col2, #T_74efe_row3_col3, #T_74efe_row4_col4, #T_74efe_row5_col5, #T_74efe_row6_col6 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_74efe_row0_col1, #T_74efe_row0_col2, #T_74efe_row0_col3, #T_74efe_row0_col4, #T_74efe_row0_col5, #T_74efe_row0_col6, #T_74efe_row5_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_74efe_row1_col0 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_74efe_row1_col2 {
#   background-color: #034c78;
#   color: #f1f1f1;
# }
# #T_74efe_row1_col3, #T_74efe_row2_col1 {
#   background-color: #034b76;
#   color: #f1f1f1;
# }
# #T_74efe_row1_col4, #T_74efe_row4_col1 {
#   background-color: #034973;
#   color: #f1f1f1;
# }
# #T_74efe_row1_col5 {
#   background-color: #046097;
#   color: #f1f1f1;
# }
# #T_74efe_row1_col6 {
#   background-color: #034f7d;
#   color: #f1f1f1;
# }
# #T_74efe_row2_col0 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_74efe_row2_col4, #T_74efe_row3_col4, #T_74efe_row4_col2, #T_74efe_row4_col3 {
#   background-color: #02395a;
#   color: #f1f1f1;
# }
# #T_74efe_row2_col5 {
#   background-color: #056ba7;
#   color: #f1f1f1;
# }
# #T_74efe_row2_col6, #T_74efe_row6_col4 {
#   background-color: #045382;
#   color: #f1f1f1;
# }
# #T_74efe_row3_col0 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_74efe_row3_col1 {
#   background-color: #034a74;
#   color: #f1f1f1;
# }
# #T_74efe_row3_col5 {
#   background-color: #0569a5;
#   color: #f1f1f1;
# }
# #T_74efe_row3_col6, #T_74efe_row6_col1 {
#   background-color: #045280;
#   color: #f1f1f1;
# }
# #T_74efe_row4_col0 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_74efe_row4_col5 {
#   background-color: #04629a;
#   color: #f1f1f1;
# }
# #T_74efe_row4_col6 {
#   background-color: #03517e;
#   color: #f1f1f1;
# }
# #T_74efe_row5_col1 {
#   background-color: #056dab;
#   color: #f1f1f1;
# }
# #T_74efe_row5_col2 {
#   background-color: #2987bc;
#   color: #f1f1f1;
# }
# #T_74efe_row5_col3 {
#   background-color: #2182b9;
#   color: #f1f1f1;
# }
# #T_74efe_row5_col4 {
#   background-color: #056fae;
#   color: #f1f1f1;
# }
# #T_74efe_row5_col6 {
#   background-color: #046096;
#   color: #f1f1f1;
# }
# #T_74efe_row6_col0 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_74efe_row6_col2 {
#   background-color: #04588a;
#   color: #f1f1f1;
# }
# #T_74efe_row6_col3 {
#   background-color: #045687;
#   color: #f1f1f1;
# }
# #T_74efe_row6_col5 {
#   background-color: #04598c;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_74efe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_74efe_level0_col0" class="col_heading level0 col0" >Species</th>
#       <th id="T_74efe_level0_col1" class="col_heading level0 col1" >Weight</th>
#       <th id="T_74efe_level0_col2" class="col_heading level0 col2" >Length1</th>
#       <th id="T_74efe_level0_col3" class="col_heading level0 col3" >Length2</th>
#       <th id="T_74efe_level0_col4" class="col_heading level0 col4" >Length3</th>
#       <th id="T_74efe_level0_col5" class="col_heading level0 col5" >Height</th>
#       <th id="T_74efe_level0_col6" class="col_heading level0 col6" >Width</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_74efe_level0_row0" class="row_heading level0 row0" >Species</th>
#       <td id="T_74efe_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_74efe_row0_col1" class="data row0 col1" >-0.176800</td>
#       <td id="T_74efe_row0_col2" class="data row0 col2" >-0.101200</td>
#       <td id="T_74efe_row0_col3" class="data row0 col3" >-0.118400</td>
#       <td id="T_74efe_row0_col4" class="data row0 col4" >-0.209500</td>
#       <td id="T_74efe_row0_col5" class="data row0 col5" >-0.697000</td>
#       <td id="T_74efe_row0_col6" class="data row0 col6" >-0.315200</td>
#     </tr>
#     <tr>
#       <th id="T_74efe_level0_row1" class="row_heading level0 row1" >Weight</th>
#       <td id="T_74efe_row1_col0" class="data row1 col0" >-0.176800</td>
#       <td id="T_74efe_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_74efe_row1_col2" class="data row1 col2" >0.915700</td>
#       <td id="T_74efe_row1_col3" class="data row1 col3" >0.918600</td>
#       <td id="T_74efe_row1_col4" class="data row1 col4" >0.923000</td>
#       <td id="T_74efe_row1_col5" class="data row1 col5" >0.724300</td>
#       <td id="T_74efe_row1_col6" class="data row1 col6" >0.886500</td>
#     </tr>
#     <tr>
#       <th id="T_74efe_level0_row2" class="row_heading level0 row2" >Length1</th>
#       <td id="T_74efe_row2_col0" class="data row2 col0" >-0.101200</td>
#       <td id="T_74efe_row2_col1" class="data row2 col1" >0.915700</td>
#       <td id="T_74efe_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_74efe_row2_col3" class="data row2 col3" >0.999500</td>
#       <td id="T_74efe_row2_col4" class="data row2 col4" >0.992000</td>
#       <td id="T_74efe_row2_col5" class="data row2 col5" >0.625400</td>
#       <td id="T_74efe_row2_col6" class="data row2 col6" >0.867000</td>
#     </tr>
#     <tr>
#       <th id="T_74efe_level0_row3" class="row_heading level0 row3" >Length2</th>
#       <td id="T_74efe_row3_col0" class="data row3 col0" >-0.118400</td>
#       <td id="T_74efe_row3_col1" class="data row3 col1" >0.918600</td>
#       <td id="T_74efe_row3_col2" class="data row3 col2" >0.999500</td>
#       <td id="T_74efe_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_74efe_row3_col4" class="data row3 col4" >0.994100</td>
#       <td id="T_74efe_row3_col5" class="data row3 col5" >0.640400</td>
#       <td id="T_74efe_row3_col6" class="data row3 col6" >0.873500</td>
#     </tr>
#     <tr>
#       <th id="T_74efe_level0_row4" class="row_heading level0 row4" >Length3</th>
#       <td id="T_74efe_row4_col0" class="data row4 col0" >-0.209500</td>
#       <td id="T_74efe_row4_col1" class="data row4 col1" >0.923000</td>
#       <td id="T_74efe_row4_col2" class="data row4 col2" >0.992000</td>
#       <td id="T_74efe_row4_col3" class="data row4 col3" >0.994100</td>
#       <td id="T_74efe_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_74efe_row4_col5" class="data row4 col5" >0.703400</td>
#       <td id="T_74efe_row4_col6" class="data row4 col6" >0.878500</td>
#     </tr>
#     <tr>
#       <th id="T_74efe_level0_row5" class="row_heading level0 row5" >Height</th>
#       <td id="T_74efe_row5_col0" class="data row5 col0" >-0.697000</td>
#       <td id="T_74efe_row5_col1" class="data row5 col1" >0.724300</td>
#       <td id="T_74efe_row5_col2" class="data row5 col2" >0.625400</td>
#       <td id="T_74efe_row5_col3" class="data row5 col3" >0.640400</td>
#       <td id="T_74efe_row5_col4" class="data row5 col4" >0.703400</td>
#       <td id="T_74efe_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_74efe_row5_col6" class="data row5 col6" >0.792900</td>
#     </tr>
#     <tr>
#       <th id="T_74efe_level0_row6" class="row_heading level0 row6" >Width</th>
#       <td id="T_74efe_row6_col0" class="data row6 col0" >-0.315200</td>
#       <td id="T_74efe_row6_col1" class="data row6 col1" >0.886500</td>
#       <td id="T_74efe_row6_col2" class="data row6 col2" >0.867000</td>
#       <td id="T_74efe_row6_col3" class="data row6 col3" >0.873500</td>
#       <td id="T_74efe_row6_col4" class="data row6 col4" >0.878500</td>
#       <td id="T_74efe_row6_col5" class="data row6 col5" >0.792900</td>
#       <td id="T_74efe_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
data_x = df.drop(['Species','Weight','Height'], axis=1)
data_y = df.Weight

# %%
data_x
# Out:
#      Length1  Length2  Length3   Width
# 0       23.2     25.4     30.0  4.0200
# 1       24.0     26.3     31.2  4.3056
# 2       23.9     26.5     31.1  4.6961
# 3       26.3     29.0     33.5  4.4555
# 4       26.5     29.0     34.0  5.1340
# ..       ...      ...      ...     ...
# 154     11.5     12.2     13.4  1.3936
# 155     11.7     12.4     13.5  1.2690
# 156     12.1     13.0     13.8  1.2558
# 157     13.2     14.3     15.2  2.0672
# 158     13.8     15.0     16.2  1.8792
#
# [159 rows x 4 columns]

# %%
train_x, test_x, train_y, test_y = train_test_split(data_x,data_y,test_size=0.2)

# %%
linear_reg = LinearRegression()

# %%
linear_reg.fit(train_x,train_y)
# Out:
# LinearRegression()

# %%
y_predicted = linear_reg.predict(test_x)

# %%
print(f'La calificacion de prediccion: {round(linear_reg.score(test_x, test_y),4)*100}%')
# Out:
# La calificacion de prediccion: 86.53999999999999%
