# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('twitchdata-update.csv')

# %%
df.head()
# Out:
#     Channel  Watch time(Minutes)  Stream time(minutes)  Peak viewers  \
# 0     xQcOW           6196161750                215250        222720
# 1  summit1g           6091677300                211845        310998
# 2    Gaules           5644590915                515280        387315
# 3  ESL_CSGO           3970318140                517740        300575
# 4      Tfue           3671000070                123660        285644
#
#    Average viewers  Followers  Followers gained  Views gained  Partnered  \
# 0            27716    3246298           1734810      93036735       True
# 1            25610    5310163           1370184      89705964       True
# 2            10976    1767635           1023779     102611607       True
# 3             7714    3944850            703986     106546942       True
# 4            29602    8938903           2068424      78998587       True
#
#    Mature    Language
# 0   False     English
# 1   False     English
# 2    True  Portuguese
# ...

# %%
df.dtypes
# Out:
# Channel                 object
# Watch time(Minutes)      int64
# Stream time(minutes)     int64
# Peak viewers             int64
# Average viewers          int64
# Followers                int64
# Followers gained         int64
# Views gained             int64
# Partnered                 bool
# Mature                    bool
# Language                object
# dtype: object

# %%
dflimpio = df

# %%
dflimpio.head()
# Out:
#     Channel  Watch time(Minutes)  Stream time(minutes)  Peak viewers  \
# 0     xQcOW           6196161750                215250        222720
# 1  summit1g           6091677300                211845        310998
# 2    Gaules           5644590915                515280        387315
# 3  ESL_CSGO           3970318140                517740        300575
# 4      Tfue           3671000070                123660        285644
#
#    Average viewers  Followers  Followers gained  Views gained  Partnered  \
# 0            27716    3246298           1734810      93036735       True
# 1            25610    5310163           1370184      89705964       True
# 2            10976    1767635           1023779     102611607       True
# 3             7714    3944850            703986     106546942       True
# 4            29602    8938903           2068424      78998587       True
#
#    Mature    Language
# 0   False     English
# 1   False     English
# 2    True  Portuguese
# ...

# %%
labeler_Language = LabelEncoder()
labeler_Channel = LabelEncoder()

# %%
labeler_Language.fit(dflimpio['Language'])
labeler_Channel.fit(dflimpio['Channel'])
# Out:
# LabelEncoder()

# %%
dflimpio['Language'] = labeler_Language.transform(dflimpio['Language'])
dflimpio['Channel'] = labeler_Channel.transform(dflimpio['Channel'])

# %%
corr = dflimpio.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_17818_row0_col0, #T_17818_row1_col1, #T_17818_row2_col2, #T_17818_row3_col3, #T_17818_row4_col4, #T_17818_row5_col5, #T_17818_row6_col6, #T_17818_row7_col7, #T_17818_row8_col8, #T_17818_row9_col9, #T_17818_row10_col10 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_17818_row0_col1, #T_17818_row1_col10, #T_17818_row3_col0, #T_17818_row9_col8 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_17818_row0_col2, #T_17818_row10_col4 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_17818_row0_col3, #T_17818_row6_col0, #T_17818_row8_col10 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_17818_row0_col4, #T_17818_row8_col2, #T_17818_row8_col4 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_17818_row0_col5, #T_17818_row2_col8, #T_17818_row4_col8 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_17818_row0_col6, #T_17818_row10_col2 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# ...

# %%
data_x = dflimpio.drop(['Language','Peak viewers','Average viewers','Views gained'], axis=1)

# %%
data_y = dflimpio['Language']

# %%
train_x, test_x, train_y, test_y = train_test_split(data_x, data_y, test_size=0.2)

# %%
model_kneigh = KNeighborsClassifier(n_neighbors=3)

# %%
model_tree = DecisionTreeClassifier()

# %%
model_forest = RandomForestClassifier()

# %%
model_kneigh.fit(train_x, train_y)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
model_tree.fit(train_x, train_y)
# Out:
# DecisionTreeClassifier()

# %%
model_forest.fit(train_x, train_y)
# Out:
# RandomForestClassifier()

# %%
print(f'Score del modelo KNeighborsClassifier: {round(model_kneigh.score(test_x, test_y),4)*100}%')
# Out:
# Score del modelo KNeighborsClassifier: 37.5%

# %%
print(f'Score del modelo DecisionTreeClassifier: {round(model_tree.score(test_x, test_y),4)*100}%')
# Out:
# Score del modelo DecisionTreeClassifier: 39.5%

# %%
print(f'Score del modelo RandomForestClassifier: {round(model_forest.score(test_x, test_y),4)*100}%')
# Out:
# Score del modelo RandomForestClassifier: 55.00000000000001%

# %%
data_x
# Out:
#      Channel  Watch time(Minutes)  Stream time(minutes)  Followers  \
# 0        893           6196161750                215250    3246298
# 1        872           6091677300                211845    5310163
# 2        226           5644590915                515280    1767635
# 3        172           3970318140                517740    3944850
# 4        600           3671000070                123660    8938903
# ..       ...                  ...                   ...        ...
# 995      326            122524635                 13560     601927
# 996      955            122523705                153000     213212
# 997      950            122452320                217410     109068
# 998       32            122311065                104745     547446
# 999      487            122192850                 99180     178553
#
#      Followers gained  Partnered  Mature
# 0             1734810       True   False
# 1             1370184       True   False
# ...

# %%
channel = labeler_Channel.transform(['summit1g'])
watch_time = 1000000
Stream_time = 100
followers = 1000000
followers_gained = 1000000
partenership    = 1
mature = 1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Windows\Documents\Trabajos de clase\Algoritmica Avanzada\algoritmica-2023-2\tareas\christian-richter\practico_3\pre-exam.ipynb Cell 24 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Windows/Documents/Trabajos%20de%20clase/Algoritmica%20Avanzada/algoritmica-2023-2/tareas/christian-richter/practico_3/pre-exam.ipynb#Y122sZmlsZQ%3D%3D?line=0'>1</a> channel = labeler_Channel.transform(['summit1g'])
#       <a href='vscode-notebook-cell:/c%3A/Users/Windows/Documents/Trabajos%20de%20clase/Algoritmica%20Avanzada/algoritmica-2023-2/tareas/christian-richter/practico_3/pre-exam.ipynb#Y122sZmlsZQ%3D%3D?line=1'>2</a> watch_time = 1000000
# ...

# %% [markdown]
# no se porque falla cada rato eso, intente buscando y no logre encontrar que pasa
