# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
## cargando el dataset
df = pd.read_csv('dataset_fish.csv')

# %%
## vamos el tipo de datos del dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Species  159 non-null    object
#  1   Weight   159 non-null    float64
#  2   Length1  159 non-null    float64
#  3   Length2  159 non-null    float64
#  4   Length3  159 non-null    float64
#  5   Height   159 non-null    float64
#  6   Width    159 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 8.8+ KB

# %%
df.head()
# Out:
#   Species  Weight  Length1  Length2  Length3   Height   Width
# 0   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340

# %%
## distribucion de las especies
df.Species.unique()
# Out:
# array(['Bream', 'Roach', 'Whitefish', 'Parkki', 'Perch', 'Pike', 'Smelt'],
#       dtype=object)

# %%
## convertimos elos nombres de las especies a numeros
df.Species = df.Species.map({'Bream':1, 'Roach':2, 'Whitefish':3, 'Parkki':4, 'Perch':5, 'Pike':6, 'Smelt':7})

# %%
df.head()
# Out:
#    Species  Weight  Length1  Length2  Length3   Height   Width
# 0        1   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1        1   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2        1   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3        1   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4        1   430.0     26.5     29.0     34.0  12.4440  5.1340

# %%
df.Species.unique()
# Out:
# array([1, 2, 3, 4, 5, 6, 7], dtype=int64)

# %%
df.describe()
# Out:
#           Species       Weight     Length1     Length2     Length3  \
# count  159.000000   159.000000  159.000000  159.000000  159.000000
# mean     3.880503   398.326415   26.247170   28.415723   31.227044
# std      2.026298   357.978317    9.996441   10.716328   11.610246
# min      1.000000     0.000000    7.500000    8.400000    8.800000
# 25%      2.000000   120.000000   19.050000   21.000000   23.150000
# 50%      5.000000   273.000000   25.200000   27.300000   29.400000
# 75%      5.000000   650.000000   32.700000   35.500000   39.650000
# max      7.000000  1650.000000   59.000000   63.400000   68.000000
#
#            Height       Width
# count  159.000000  159.000000
# mean     8.970994    4.417486
# std      4.286208    1.685804
# min      1.728400    1.047600
# 25%      5.944800    3.385650
# 50%      7.786000    4.248500
# 75%     12.365900    5.584500
# max     18.957000    8.142000

# %%
## rredondemos los valores
corr = round(df.corr(), 4)
corr.style.background_gradient()
# Out:
# <style type="text/css">
# #T_200da_row0_col0, #T_200da_row1_col1, #T_200da_row2_col2, #T_200da_row2_col3, #T_200da_row3_col2, #T_200da_row3_col3, #T_200da_row4_col4, #T_200da_row5_col5, #T_200da_row6_col6 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_200da_row0_col1, #T_200da_row0_col2, #T_200da_row0_col3, #T_200da_row0_col4, #T_200da_row0_col5, #T_200da_row0_col6, #T_200da_row5_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_200da_row1_col0 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_200da_row1_col2 {
#   background-color: #034c78;
#   color: #f1f1f1;
# }
# #T_200da_row1_col3, #T_200da_row2_col1 {
#   background-color: #034b76;
#   color: #f1f1f1;
# }
# #T_200da_row1_col4, #T_200da_row4_col1 {
#   background-color: #034973;
#   color: #f1f1f1;
# }
# #T_200da_row1_col5 {
#   background-color: #046097;
#   color: #f1f1f1;
# }
# #T_200da_row1_col6 {
#   background-color: #034f7d;
#   color: #f1f1f1;
# }
# #T_200da_row2_col0 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_200da_row2_col4, #T_200da_row3_col4, #T_200da_row4_col2, #T_200da_row4_col3 {
#   background-color: #02395a;
#   color: #f1f1f1;
# }
# #T_200da_row2_col5 {
#   background-color: #056ba7;
#   color: #f1f1f1;
# }
# #T_200da_row2_col6, #T_200da_row6_col4 {
#   background-color: #045382;
#   color: #f1f1f1;
# }
# #T_200da_row3_col0 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_200da_row3_col1 {
#   background-color: #034a74;
#   color: #f1f1f1;
# }
# #T_200da_row3_col5 {
#   background-color: #0569a5;
#   color: #f1f1f1;
# }
# #T_200da_row3_col6, #T_200da_row6_col1 {
#   background-color: #045280;
#   color: #f1f1f1;
# }
# #T_200da_row4_col0 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_200da_row4_col5 {
#   background-color: #04629a;
#   color: #f1f1f1;
# }
# #T_200da_row4_col6 {
#   background-color: #03517e;
#   color: #f1f1f1;
# }
# #T_200da_row5_col1 {
#   background-color: #056dab;
#   color: #f1f1f1;
# }
# #T_200da_row5_col2 {
#   background-color: #2987bc;
#   color: #f1f1f1;
# }
# #T_200da_row5_col3 {
#   background-color: #2182b9;
#   color: #f1f1f1;
# }
# #T_200da_row5_col4 {
#   background-color: #056fae;
#   color: #f1f1f1;
# }
# #T_200da_row5_col6 {
#   background-color: #046096;
#   color: #f1f1f1;
# }
# #T_200da_row6_col0 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_200da_row6_col2 {
#   background-color: #04588a;
#   color: #f1f1f1;
# }
# #T_200da_row6_col3 {
#   background-color: #045687;
#   color: #f1f1f1;
# }
# #T_200da_row6_col5 {
#   background-color: #04598c;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_200da">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_200da_level0_col0" class="col_heading level0 col0" >Species</th>
#       <th id="T_200da_level0_col1" class="col_heading level0 col1" >Weight</th>
#       <th id="T_200da_level0_col2" class="col_heading level0 col2" >Length1</th>
#       <th id="T_200da_level0_col3" class="col_heading level0 col3" >Length2</th>
#       <th id="T_200da_level0_col4" class="col_heading level0 col4" >Length3</th>
#       <th id="T_200da_level0_col5" class="col_heading level0 col5" >Height</th>
#       <th id="T_200da_level0_col6" class="col_heading level0 col6" >Width</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_200da_level0_row0" class="row_heading level0 row0" >Species</th>
#       <td id="T_200da_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_200da_row0_col1" class="data row0 col1" >-0.176800</td>
#       <td id="T_200da_row0_col2" class="data row0 col2" >-0.101200</td>
#       <td id="T_200da_row0_col3" class="data row0 col3" >-0.118400</td>
#       <td id="T_200da_row0_col4" class="data row0 col4" >-0.209500</td>
#       <td id="T_200da_row0_col5" class="data row0 col5" >-0.697000</td>
#       <td id="T_200da_row0_col6" class="data row0 col6" >-0.315200</td>
#     </tr>
#     <tr>
#       <th id="T_200da_level0_row1" class="row_heading level0 row1" >Weight</th>
#       <td id="T_200da_row1_col0" class="data row1 col0" >-0.176800</td>
#       <td id="T_200da_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_200da_row1_col2" class="data row1 col2" >0.915700</td>
#       <td id="T_200da_row1_col3" class="data row1 col3" >0.918600</td>
#       <td id="T_200da_row1_col4" class="data row1 col4" >0.923000</td>
#       <td id="T_200da_row1_col5" class="data row1 col5" >0.724300</td>
#       <td id="T_200da_row1_col6" class="data row1 col6" >0.886500</td>
#     </tr>
#     <tr>
#       <th id="T_200da_level0_row2" class="row_heading level0 row2" >Length1</th>
#       <td id="T_200da_row2_col0" class="data row2 col0" >-0.101200</td>
#       <td id="T_200da_row2_col1" class="data row2 col1" >0.915700</td>
#       <td id="T_200da_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_200da_row2_col3" class="data row2 col3" >0.999500</td>
#       <td id="T_200da_row2_col4" class="data row2 col4" >0.992000</td>
#       <td id="T_200da_row2_col5" class="data row2 col5" >0.625400</td>
#       <td id="T_200da_row2_col6" class="data row2 col6" >0.867000</td>
#     </tr>
#     <tr>
#       <th id="T_200da_level0_row3" class="row_heading level0 row3" >Length2</th>
#       <td id="T_200da_row3_col0" class="data row3 col0" >-0.118400</td>
#       <td id="T_200da_row3_col1" class="data row3 col1" >0.918600</td>
#       <td id="T_200da_row3_col2" class="data row3 col2" >0.999500</td>
#       <td id="T_200da_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_200da_row3_col4" class="data row3 col4" >0.994100</td>
#       <td id="T_200da_row3_col5" class="data row3 col5" >0.640400</td>
#       <td id="T_200da_row3_col6" class="data row3 col6" >0.873500</td>
#     </tr>
#     <tr>
#       <th id="T_200da_level0_row4" class="row_heading level0 row4" >Length3</th>
#       <td id="T_200da_row4_col0" class="data row4 col0" >-0.209500</td>
#       <td id="T_200da_row4_col1" class="data row4 col1" >0.923000</td>
#       <td id="T_200da_row4_col2" class="data row4 col2" >0.992000</td>
#       <td id="T_200da_row4_col3" class="data row4 col3" >0.994100</td>
#       <td id="T_200da_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_200da_row4_col5" class="data row4 col5" >0.703400</td>
#       <td id="T_200da_row4_col6" class="data row4 col6" >0.878500</td>
#     </tr>
#     <tr>
#       <th id="T_200da_level0_row5" class="row_heading level0 row5" >Height</th>
#       <td id="T_200da_row5_col0" class="data row5 col0" >-0.697000</td>
#       <td id="T_200da_row5_col1" class="data row5 col1" >0.724300</td>
#       <td id="T_200da_row5_col2" class="data row5 col2" >0.625400</td>
#       <td id="T_200da_row5_col3" class="data row5 col3" >0.640400</td>
#       <td id="T_200da_row5_col4" class="data row5 col4" >0.703400</td>
#       <td id="T_200da_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_200da_row5_col6" class="data row5 col6" >0.792900</td>
#     </tr>
#     <tr>
#       <th id="T_200da_level0_row6" class="row_heading level0 row6" >Width</th>
#       <td id="T_200da_row6_col0" class="data row6 col0" >-0.315200</td>
#       <td id="T_200da_row6_col1" class="data row6 col1" >0.886500</td>
#       <td id="T_200da_row6_col2" class="data row6 col2" >0.867000</td>
#       <td id="T_200da_row6_col3" class="data row6 col3" >0.873500</td>
#       <td id="T_200da_row6_col4" class="data row6 col4" >0.878500</td>
#       <td id="T_200da_row6_col5" class="data row6 col5" >0.792900</td>
#       <td id="T_200da_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
data_x = df.drop(['Weight'], axis=1)
data_y = df.Weight

# %%
data_x
# Out:
#      Species  Length1  Length2  Length3   Height   Width
# 0          1     23.2     25.4     30.0  11.5200  4.0200
# 1          1     24.0     26.3     31.2  12.4800  4.3056
# 2          1     23.9     26.5     31.1  12.3778  4.6961
# 3          1     26.3     29.0     33.5  12.7300  4.4555
# 4          1     26.5     29.0     34.0  12.4440  5.1340
# ..       ...      ...      ...      ...      ...     ...
# 154        7     11.5     12.2     13.4   2.0904  1.3936
# 155        7     11.7     12.4     13.5   2.4300  1.2690
# 156        7     12.1     13.0     13.8   2.2770  1.2558
# 157        7     13.2     14.3     15.2   2.8728  2.0672
# 158        7     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 6 columns]

# %%
data_y
# Out:
# 0      242.0
# 1      290.0
# 2      340.0
# 3      363.0
# 4      430.0
#        ...
# 154     12.2
# 155     13.4
# 156     12.2
# 157     19.7
# 158     19.9
# Name: Weight, Length: 159, dtype: float64

# %%
train_x, test_x, train_y, test_y = train_test_split(data_x, data_y, test_size=0.2)

# %%
## creamos el modelo
model = Ridge()

# %%
## entrenamos el modelo
model.fit(train_x, train_y)
# Out:
# Ridge()

# %%
## evaluamos el modelo
y_predicted = model.predict(test_x)

# %%
train_x
# Out:
#      Species  Length1  Length2  Length3   Height   Width
# 49         2     22.0     23.4     26.7   6.9153  3.6312
# 58         3     28.5     31.0     34.0  10.7440  6.5620
# 6          1     26.8     29.7     34.5  14.1795  5.2785
# 26         1     32.0     35.0     40.6  16.3618  6.0900
# 150        7     10.8     11.3     12.6   1.9782  1.2852
# ..       ...      ...      ...      ...      ...     ...
# 47         2     21.1     22.5     25.0   6.4000  3.8000
# 1          1     24.0     26.3     31.2  12.4800  4.3056
# 30         1     35.0     38.5     44.1  18.0369  6.3063
# 121        5     37.0     40.0     42.4  12.3808  7.4624
# 112        5     34.0     36.5     39.0  10.8810  6.8640
#
# [127 rows x 6 columns]

# %%
print(f'Calificacion de prediccion:{round(model.score(test_x, test_y),4) * 100 }%')
# Out:
# Calificacion de prediccion:89.49000000000001%
