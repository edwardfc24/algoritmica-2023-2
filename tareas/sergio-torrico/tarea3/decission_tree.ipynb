# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('riceClassification.csv')

# %%
df.head()
# Out:
#    id  Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 0   1  4537        92.229316        64.012769      0.719916        4677
# 1   2  2872        74.691881        51.400454      0.725553        3015
# 2   3  3048        76.293164        52.043491      0.731211        3132
# 3   4  3073        77.033628        51.928487      0.738639        3157
# 4   5  3693        85.124785        56.374021      0.749282        3802
#
#    EquivDiameter    Extent  Perimeter  Roundness  AspectRation  Class
# 0      76.004525  0.657536    273.085   0.764510      1.440796      1
# 1      60.471018  0.713009    208.317   0.831658      1.453137      1
# 2      62.296341  0.759153    210.012   0.868434      1.465950      1
# 3      62.551300  0.783529    210.657   0.870203      1.483456      1
# 4      68.571668  0.769375    230.332   0.874743      1.510000      1

# %%
df.drop(['id', 'AspectRation'], axis='columns', inplace=True)

# %%
df.Class.unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df
# Out:
#        Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 0      4537        92.229316        64.012769      0.719916        4677
# 1      2872        74.691881        51.400454      0.725553        3015
# 2      3048        76.293164        52.043491      0.731211        3132
# 3      3073        77.033628        51.928487      0.738639        3157
# 4      3693        85.124785        56.374021      0.749282        3802
# ...     ...              ...              ...           ...         ...
# 18180  5853       148.624571        51.029281      0.939210        6008
# 18181  7585       169.593996        58.141659      0.939398        7806
# 18182  6365       154.777085        52.908085      0.939760        6531
# 18183  5960       151.397924        51.474600      0.940427        6189
# 18184  6134       153.081981        51.590606      0.941500        6283
#
#        EquivDiameter    Extent  Perimeter  Roundness  Class
# ...

# %%
df.dtypes
# Out:
# Area                 int64
# MajorAxisLength    float64
# MinorAxisLength    float64
# Eccentricity       float64
# ConvexArea           int64
# EquivDiameter      float64
# Extent             float64
# Perimeter          float64
# Roundness          float64
# Class                int64
# dtype: object

# %%
df.describe()
# Out:
#                Area  MajorAxisLength  MinorAxisLength  Eccentricity  \
# count  18185.000000     18185.000000     18185.000000  18185.000000
# mean    7036.492989       151.680754        59.807851      0.915406
# std     1467.197150        12.376402        10.061653      0.030575
# min     2522.000000        74.133114        34.409894      0.676647
# 25%     5962.000000       145.675910        51.393151      0.891617
# 50%     6660.000000       153.883750        55.724288      0.923259
# 75%     8423.000000       160.056214        70.156593      0.941372
# max    10210.000000       183.211434        82.550762      0.966774
#
#          ConvexArea  EquivDiameter        Extent     Perimeter     Roundness  \
# count  18185.000000   18185.000000  18185.000000  18185.000000  18185.000000
# mean    7225.817872      94.132952      0.616653    351.606949      0.707998
# std     1502.006571       9.906250      0.104389     29.500620      0.067310
# ...

# %%
corr = round(df.corr(), 4)
corr.style.background_gradient()
# Out:
# <style type="text/css">
# #T_68b80_row0_col0, #T_68b80_row0_col4, #T_68b80_row0_col5, #T_68b80_row1_col1, #T_68b80_row2_col2, #T_68b80_row3_col3, #T_68b80_row4_col0, #T_68b80_row4_col4, #T_68b80_row4_col5, #T_68b80_row5_col0, #T_68b80_row5_col4, #T_68b80_row5_col5, #T_68b80_row6_col6, #T_68b80_row7_col7, #T_68b80_row8_col8, #T_68b80_row9_col9 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_68b80_row0_col1, #T_68b80_row6_col8 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# #T_68b80_row0_col2, #T_68b80_row2_col0, #T_68b80_row4_col2 {
#   background-color: #034267;
#   color: #f1f1f1;
# }
# #T_68b80_row0_col3, #T_68b80_row4_col3 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_68b80_row0_col6, #T_68b80_row4_col6, #T_68b80_row5_col6 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_68b80_row0_col7 {
#   background-color: #034c78;
#   color: #f1f1f1;
# }
# #T_68b80_row0_col8 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# ...

# %%
data_x = df.drop(['Class'], axis='columns')
data_y = df.Class

# %%
data_x
# Out:
#        Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 0      4537        92.229316        64.012769      0.719916        4677
# 1      2872        74.691881        51.400454      0.725553        3015
# 2      3048        76.293164        52.043491      0.731211        3132
# 3      3073        77.033628        51.928487      0.738639        3157
# 4      3693        85.124785        56.374021      0.749282        3802
# ...     ...              ...              ...           ...         ...
# 18180  5853       148.624571        51.029281      0.939210        6008
# 18181  7585       169.593996        58.141659      0.939398        7806
# 18182  6365       154.777085        52.908085      0.939760        6531
# 18183  5960       151.397924        51.474600      0.940427        6189
# 18184  6134       153.081981        51.590606      0.941500        6283
#
#        EquivDiameter    Extent  Perimeter  Roundness
# ...

# %%
data_y
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 18180    0
# 18181    0
# 18182    0
# 18183    0
# 18184    0
# Name: Class, Length: 18185, dtype: int64

# %%
decission_model = DecisionTreeClassifier()

# %%
train_x, test_x, train_y, test_y = train_test_split(data_x, data_y, test_size=0.1)

# %%
decission_model.fit(train_x, train_y)
# Out:
# DecisionTreeClassifier()

# %%
y_predicted = decission_model.predict(test_x)

# %%
print(f'Score del modelo: {round(decission_model.score(test_x, test_y), 4) * 100}%')
# Out:
# Score del modelo: 98.57000000000001%

# %%
df
# Out:
#        Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 0      4537        92.229316        64.012769      0.719916        4677
# 1      2872        74.691881        51.400454      0.725553        3015
# 2      3048        76.293164        52.043491      0.731211        3132
# 3      3073        77.033628        51.928487      0.738639        3157
# 4      3693        85.124785        56.374021      0.749282        3802
# ...     ...              ...              ...           ...         ...
# 18180  5853       148.624571        51.029281      0.939210        6008
# 18181  7585       169.593996        58.141659      0.939398        7806
# 18182  6365       154.777085        52.908085      0.939760        6531
# 18183  5960       151.397924        51.474600      0.940427        6189
# 18184  6134       153.081981        51.590606      0.941500        6283
#
#        EquivDiameter    Extent  Perimeter  Roundness  Class
# ...

# %%
data_x
# Out:
#        Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 0      4537        92.229316        64.012769      0.719916        4677
# 1      2872        74.691881        51.400454      0.725553        3015
# 2      3048        76.293164        52.043491      0.731211        3132
# 3      3073        77.033628        51.928487      0.738639        3157
# 4      3693        85.124785        56.374021      0.749282        3802
# ...     ...              ...              ...           ...         ...
# 18180  5853       148.624571        51.029281      0.939210        6008
# 18181  7585       169.593996        58.141659      0.939398        7806
# 18182  6365       154.777085        52.908085      0.939760        6531
# 18183  5960       151.397924        51.474600      0.940427        6189
# 18184  6134       153.081981        51.590606      0.941500        6283
#
#        EquivDiameter    Extent  Perimeter  Roundness
# ...

# %%
clasificacion = ['bueno', 'malo']

Area = 1000.0
MajorAxisLength = 13.2
MinorAxisLength = 11.8
Eccentricity = 10.6
ConvexArea = 19.5
EquivDiameter = 12.5
Extent = 10.5
Perimeter = 11.5
Roundness = 10.5

# %%
def rice_classify(model, Area, MajorAxisLength, MinorAxisLength, Eccentricity, ConvexArea, EquivDiameter, Extent, Perimeter, Roundness):
    predicted =  model.predict([[Area, MajorAxisLength, MinorAxisLength, Eccentricity, ConvexArea, EquivDiameter, Extent, Perimeter, Roundness]])
    print(f'El arroz de area{Area}, de mayor longitud {MajorAxisLength} y de menor longitud: {MinorAxisLength}, y de exentricidad: {Eccentricity} y de area convexa {ConvexArea} que tiene un diametro de: {EquivDiameter} con un perimetro de: {Perimeter} entrenamiento, con puntuacion de redondez: {Roundness} sera {clasificacion[predicted[0]]}')

# %%
rice_classify(decission_model, Area, MajorAxisLength, MinorAxisLength, Eccentricity, ConvexArea, EquivDiameter, Extent, Perimeter, Roundness)
# Out:
# El arroz de area1000.0, de mayor longitud 13.2 y de menor longitud: 11.8, y de exentricidad: 10.6 y de area convexa 19.5 que tiene un diametro de: 12.5 con un perimetro de: 11.5 entrenamiento, con puntuacion de redondez: 10.5 sera malo
# d:\01 User sergio\Documentos\Python proyectos\entorno_virtual\entorno_virtual\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
